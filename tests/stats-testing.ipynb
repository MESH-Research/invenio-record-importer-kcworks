# %%
from flask import current_app as app
from opensearchpy.client import OpenSearch
from opensearchpy.helpers.search import Search
from pprint import pprint

client = OpenSearch(
    hosts=[{"host": "localhost", "port": 9200}],
    http_auth=("admin", "admin"),
    scheme="http",
)
search = Search(
    using=client,
    index="events-stats-record-view",
)
search._params["size"] = 10000
search = search.filter("term", country="imported").filter("term", recid="j4ezy-qtf2")
# search = search.filter("term", unique_session_id="0a0c3bb63269a28073c7d5e9265040f906121264526599c4a1f60e6b")
# search = search.filter("range", timestamp={"gte": "2024-01-01T00:00:00", "lte": "2025-01-01T00:00:00"})
terms = search.aggs.bucket("terms", "terms", field="unique_id")
terms.metric(
    "top_hit", "top_hits", size=10, sort={"timestamp": "desc"}
)
terms.metric(
    "unique_count",
    "cardinality",
    field="unique_session_id",
    precision_threshold=2000,
)
# one bucket per document with all that document's events,
# each bucket has
# - "doc_count" with the total number of events
# - "unique_count" with the number of unique unique_session_id values

response = list(search.scan())
print(len(response))
ids = []
if len(response) > 0:
    pprint(response[0].to_dict())
for r in response:
    if r.to_dict()["unique_session_id"] not in ids:
        ids.append(r.to_dict()["unique_session_id"])
    else:
        print("DUPLICATE unique_session_id")
        print(r.to_dict()["unique_session_id"])
        print(r.to_dict())

response = search.execute()
print(response.hits.total.value)
pprint([{k: v for k, v in b.items() if k in ["key", "doc_count", "unique_count"]} for b in response.to_dict()['aggregations']['terms']['buckets']])
# Out:
# 0
# 0
# []

# %%
from flask import current_app as app
from opensearchpy.client import OpenSearch
from opensearchpy.helpers.search import Search
from pprint import pprint

client = OpenSearch(
    hosts=[{"host": "localhost", "port": 9200}],
    http_auth=("admin", "admin"),
    scheme="http",
)
search = Search(
    using=client,
    index="stats-record-view",
)
search = search.filter("term", recid="ftrya-g6y46")
print(search.count())
# search = search.filter("term", timestamp="2024-01-01T00:00:00")

search._params["size"] = 10000
response = search.execute()
print(response.hits.total.value)
print(sum([h["_source"]["count"] for h in response.to_dict()["hits"]["hits"]]))
print(sum([h["_source"]["unique_count"] for h in response.to_dict()["hits"]["hits"]]))
print([h for h in response.to_dict()["hits"]["hits"] if h["_source"]["unique_count"] != h["_source"]["count"]])
pprint(response.to_dict())
# Out:
# 20
# 20
# 20
# 20
# []
# {'_shards': {'failed': 0, 'skipped': 0, 'successful': 69, 'total': 69},
#  'hits': {'hits': [{'_id': 'ui_ftrya-g6y46-2024-01-11',
#                     '_index': 'stats-record-view-2024-01',
#                     '_score': 0.0,
#                     '_source': {'count': 1,
#                                 'parent_recid': 'jcmwp-agf17',
#                                 'recid': 'ftrya-g6y46',
#                                 'timestamp': '2024-01-11T00:00:00',
#                                 'unique_count': 1,
#                                 'unique_id': 'ui_ftrya-g6y46',
#                                 'updated_timestamp': '2024-09-18T19:34:21.021102',
#                                 'via_api': False}},
#                    {'_id': 'ui_ftrya-g6y46-2024-01-24',
#                     '_index': 'stats-record-view-2024-01',
#                     '_score': 0.0,
#                     '_source': {'count': 1,
#                                 'parent_recid': 'jcmwp-agf17',
#                                 'recid': 'ftrya-g6y46',
#                                 'timestamp': '2024-01-24T00:00:00',
#                                 'unique_count': 1,
#                                 'unique_id': 'ui_ftrya-g6y46',
#                                 'updated_timestamp': '2024-09-18T19:34:21.186841',
#                                 'via_api': False}},
#                    {'_id': 'ui_ftrya-g6y46-2024-02-05',
#                     '_index': 'stats-record-view-2024-02',
#                     '_score': 0.0,
#                     '_source': {'count': 1,
#                                 'parent_recid': 'jcmwp-agf17',
#                                 'recid': 'ftrya-g6y46',
#                                 'timestamp': '2024-02-05T00:00:00',
#                                 'unique_count': 1,
#                                 'unique_id': 'ui_ftrya-g6y46',
#                                 'updated_timestamp': '2024-09-18T19:34:21.369985',
#                                 'via_api': False}},
#                    {'_id': 'ui_ftrya-g6y46-2024-02-18',
#                     '_index': 'stats-record-view-2024-02',
#                     '_score': 0.0,
#                     '_source': {'count': 1,
#                                 'parent_recid': 'jcmwp-agf17',
#                                 'recid': 'ftrya-g6y46',
#                                 'timestamp': '2024-02-18T00:00:00',
#                                 'unique_count': 1,
#                                 'unique_id': 'ui_ftrya-g6y46',
#                                 'updated_timestamp': '2024-09-18T19:34:21.640865',
#                                 'via_api': False}},
#                    {'_id': 'ui_ftrya-g6y46-2024-03-01',
#                     '_index': 'stats-record-view-2024-03',
#                     '_score': 0.0,
#                     '_source': {'count': 1,
#                                 'parent_recid': 'jcmwp-agf17',
#                                 'recid': 'ftrya-g6y46',
#                                 'timestamp': '2024-03-01T00:00:00',
#                                 'unique_count': 1,
#                                 'unique_id': 'ui_ftrya-g6y46',
#                                 'updated_timestamp': '2024-09-18T19:34:21.793147',
#                                 'via_api': False}},
#                    {'_id': 'ui_ftrya-g6y46-2024-03-14',
#                     '_index': 'stats-record-view-2024-03',
#                     '_score': 0.0,
#                     '_source': {'count': 1,
#                                 'parent_recid': 'jcmwp-agf17',
#                                 'recid': 'ftrya-g6y46',
#                                 'timestamp': '2024-03-14T00:00:00',
#                                 'unique_count': 1,
#                                 'unique_id': 'ui_ftrya-g6y46',
#                                 'updated_timestamp': '2024-09-18T19:34:22.074084',
#                                 'via_api': False}},
#                    {'_id': 'ui_ftrya-g6y46-2024-03-26',
#                     '_index': 'stats-record-view-2024-03',
#                     '_score': 0.0,
#                     '_source': {'count': 1,
#                                 'parent_recid': 'jcmwp-agf17',
#                                 'recid': 'ftrya-g6y46',
#                                 'timestamp': '2024-03-26T00:00:00',
#                                 'unique_count': 1,
#                                 'unique_id': 'ui_ftrya-g6y46',
#                                 'updated_timestamp': '2024-09-18T19:34:22.333478',
#                                 'via_api': False}},
#                    {'_id': 'ui_ftrya-g6y46-2024-04-08',
#                     '_index': 'stats-record-view-2024-04',
#                     '_score': 0.0,
#                     '_source': {'count': 1,
#                                 'parent_recid': 'jcmwp-agf17',
#                                 'recid': 'ftrya-g6y46',
#                                 'timestamp': '2024-04-08T00:00:00',
#                                 'unique_count': 1,
#                                 'unique_id': 'ui_ftrya-g6y46',
#                                 'updated_timestamp': '2024-09-18T19:34:22.540548',
#                                 'via_api': False}},
#                    {'_id': 'ui_ftrya-g6y46-2024-04-21',
#                     '_index': 'stats-record-view-2024-04',
#                     '_score': 0.0,
#                     '_source': {'count': 1,
#                                 'parent_recid': 'jcmwp-agf17',
#                                 'recid': 'ftrya-g6y46',
#                                 'timestamp': '2024-04-21T00:00:00',
#                                 'unique_count': 1,
#                                 'unique_id': 'ui_ftrya-g6y46',
#                                 'updated_timestamp': '2024-09-18T19:34:22.666891',
#                                 'via_api': False}},
#                    {'_id': 'ui_ftrya-g6y46-2024-05-03',
#                     '_index': 'stats-record-view-2024-05',
#                     '_score': 0.0,
#                     '_source': {'count': 1,
#                                 'parent_recid': 'jcmwp-agf17',
#                                 'recid': 'ftrya-g6y46',
#                                 'timestamp': '2024-05-03T00:00:00',
#                                 'unique_count': 1,
#                                 'unique_id': 'ui_ftrya-g6y46',
#                                 'updated_timestamp': '2024-09-18T19:34:22.859982',
#                                 'via_api': False}},
#                    {'_id': 'ui_ftrya-g6y46-2024-05-16',
#                     '_index': 'stats-record-view-2024-05',
#                     '_score': 0.0,
#                     '_source': {'count': 1,
#                                 'parent_recid': 'jcmwp-agf17',
#                                 'recid': 'ftrya-g6y46',
#                                 'timestamp': '2024-05-16T00:00:00',
#                                 'unique_count': 1,
#                                 'unique_id': 'ui_ftrya-g6y46',
#                                 'updated_timestamp': '2024-09-18T19:34:23.051249',
#                                 'via_api': False}},
#                    {'_id': 'ui_ftrya-g6y46-2024-05-28',
#                     '_index': 'stats-record-view-2024-05',
#                     '_score': 0.0,
#                     '_source': {'count': 1,
#                                 'parent_recid': 'jcmwp-agf17',
#                                 'recid': 'ftrya-g6y46',
#                                 'timestamp': '2024-05-28T00:00:00',
#                                 'unique_count': 1,
#                                 'unique_id': 'ui_ftrya-g6y46',
#                                 'updated_timestamp': '2024-09-18T19:34:24.294749',
#                                 'via_api': False}},
#                    {'_id': 'ui_ftrya-g6y46-2024-06-10',
#                     '_index': 'stats-record-view-2024-06',
#                     '_score': 0.0,
#                     '_source': {'count': 1,
#                                 'parent_recid': 'jcmwp-agf17',
#                                 'recid': 'ftrya-g6y46',
#                                 'timestamp': '2024-06-10T00:00:00',
#                                 'unique_count': 1,
#                                 'unique_id': 'ui_ftrya-g6y46',
#                                 'updated_timestamp': '2024-09-18T19:34:24.415219',
#                                 'via_api': False}},
#                    {'_id': 'ui_ftrya-g6y46-2024-06-22',
#                     '_index': 'stats-record-view-2024-06',
#                     '_score': 0.0,
#                     '_source': {'count': 1,
#                                 'parent_recid': 'jcmwp-agf17',
#                                 'recid': 'ftrya-g6y46',
#                                 'timestamp': '2024-06-22T00:00:00',
#                                 'unique_count': 1,
#                                 'unique_id': 'ui_ftrya-g6y46',
#                                 'updated_timestamp': '2024-09-18T19:34:24.624473',
#                                 'via_api': False}},
#                    {'_id': 'ui_ftrya-g6y46-2024-07-05',
#                     '_index': 'stats-record-view-2024-07',
#                     '_score': 0.0,
#                     '_source': {'count': 1,
#                                 'parent_recid': 'jcmwp-agf17',
#                                 'recid': 'ftrya-g6y46',
#                                 'timestamp': '2024-07-05T00:00:00',
#                                 'unique_count': 1,
#                                 'unique_id': 'ui_ftrya-g6y46',
#                                 'updated_timestamp': '2024-09-18T19:34:24.778489',
#                                 'via_api': False}},
#                    {'_id': 'ui_ftrya-g6y46-2024-07-17',
#                     '_index': 'stats-record-view-2024-07',
#                     '_score': 0.0,
#                     '_source': {'count': 1,
#                                 'parent_recid': 'jcmwp-agf17',
#                                 'recid': 'ftrya-g6y46',
#                                 'timestamp': '2024-07-17T00:00:00',
#                                 'unique_count': 1,
#                                 'unique_id': 'ui_ftrya-g6y46',
#                                 'updated_timestamp': '2024-09-18T19:34:24.901878',
#                                 'via_api': False}},
#                    {'_id': 'ui_ftrya-g6y46-2024-07-30',
#                     '_index': 'stats-record-view-2024-07',
#                     '_score': 0.0,
#                     '_source': {'count': 1,
#                                 'parent_recid': 'jcmwp-agf17',
#                                 'recid': 'ftrya-g6y46',
#                                 'timestamp': '2024-07-30T00:00:00',
#                                 'unique_count': 1,
#                                 'unique_id': 'ui_ftrya-g6y46',
#                                 'updated_timestamp': '2024-09-18T19:34:25.018248',
#                                 'via_api': False}},
#                    {'_id': 'ui_ftrya-g6y46-2024-08-12',
#                     '_index': 'stats-record-view-2024-08',
#                     '_score': 0.0,
#                     '_source': {'count': 1,
#                                 'parent_recid': 'jcmwp-agf17',
#                                 'recid': 'ftrya-g6y46',
#                                 'timestamp': '2024-08-12T00:00:00',
#                                 'unique_count': 1,
#                                 'unique_id': 'ui_ftrya-g6y46',
#                                 'updated_timestamp': '2024-09-18T19:34:25.174057',
#                                 'via_api': False}},
#                    {'_id': 'ui_ftrya-g6y46-2024-08-24',
#                     '_index': 'stats-record-view-2024-08',
#                     '_score': 0.0,
#                     '_source': {'count': 1,
#                                 'parent_recid': 'jcmwp-agf17',
#                                 'recid': 'ftrya-g6y46',
#                                 'timestamp': '2024-08-24T00:00:00',
#                                 'unique_count': 1,
#                                 'unique_id': 'ui_ftrya-g6y46',
#                                 'updated_timestamp': '2024-09-18T19:34:25.315519',
#                                 'via_api': False}},
#                    {'_id': 'ui_ftrya-g6y46-2024-09-06',
#                     '_index': 'stats-record-view-2024-09',
#                     '_score': 0.0,
#                     '_source': {'count': 1,
#                                 'parent_recid': 'jcmwp-agf17',
#                                 'recid': 'ftrya-g6y46',
#                                 'timestamp': '2024-09-06T00:00:00',
#                                 'unique_count': 1,
#                                 'unique_id': 'ui_ftrya-g6y46',
#                                 'updated_timestamp': '2024-09-18T19:34:25.465168',
#                                 'via_api': False}}],
#           'max_score': 0.0,
#           'total': {'relation': 'eq', 'value': 20}},
#  'timed_out': False,
#  'took': 4}

# %%
from flask import current_app as app
from opensearchpy.client import OpenSearch
from opensearchpy.helpers.search import Search
from pprint import pprint

client = OpenSearch(
    hosts=[{"host": "localhost", "port": 9200}],
    http_auth=("admin", "admin"),
    scheme="http",
)
aggs_query = Search(
            using=client,
            index="stats-record-view",
        ).extra(_source=False)
aggs_query = aggs_query.filter("term", recid="b6td4-wpw6")
aggs_query = aggs_query.filter("range", timestamp={"gte": "2024-06-01T00:00:00", "lte": "2025-01-01T00:00:00"})

result = aggs_query.execute()
pprint(result.to_dict())
# Out:
# {'_shards': {'failed': 0, 'skipped': 0, 'successful': 69, 'total': 69},
#  'hits': {'hits': [],
#           'max_score': None,
#           'total': {'relation': 'eq', 'value': 0}},
#  'timed_out': False,
#  'took': 8}
