# %%
import json

file_path = '/Users/ianscott/Development/kcr-untracked-files/records-for-import.json'

with open(file_path) as file:
    data = json.load(file)

    first_object = data[0]
    pretty_printed_object = json.dumps(first_object, indent=4)

    print(pretty_printed_object)
# Out:
# {
#     "deposit_post_id": "170",
#     "total_downloads": "52",
#     "total_views": "33",
#     "submitter_login": "tsachisl",
#     "submitter_email": "Tsachisl@gmail.com",
#     "blog_id": "1000361",
#     "domain": "ajs.hcommons.org",
#     "id": "hc:10053",
#     "pid": "hc:10053",
#     "creator": "HumCORE",
#     "title": "Religious Cultural Zionism: Religion and Nationalism in the Thought of Shmuel Alexandrov",
#     "title_unchanged": "Religious Cultural Zionism: Religion and Nationalism in the Thought of Shmuel Alexandrov",
#     "abstract": "Rabbi Shmuel Alexandrov is a fascinating yet neglected thinker. In this paper I examine the earlier stage of his thought, which would serve as the basis for researching his later thought, by analyzing the discourse 'Religious Fire and National Spirit [esh dat ve'ruch leumi]'. Alexandrov is referring to the polemic between Ahad Ha'am (Asher Zvi Hirsch Ginsberg) and Moshe Leib Lilienblum which stirred up the Jewish national movement at the time. He takes the side of Ahad Ha'am, and call upon him and his fellows to join in a new national-interpretive initiative. In Alexandrov's opinion the contradiction between religious life and the sciences and enlightenment finds its dialectic culmination in Nationalism, which embodies authenticity, morality and rationality. National life will replace religious life, which hinges solely upon reward and punishment. Like Ahad Ha'am, Alexandrov combines a striving to modernize Judaism with a call to return to the traditional sources which carry its national values. For this purpose he wishes to establish a Religious-Academic institution in Jerusalem, which will engage in reinterpreting traditional sources in such a way as to remold Judaism.",
#     "abstract_unchanged": "Rabbi Shmuel Alexandrov is a fascinating yet neglected thinker. In this paper I examine the earlier stage of his thought, which would serve as the basis for researching his later thought, by analyzing the discourse 'Religious Fire and National Spirit [esh dat ve'ruch leumi]'. Alexandrov is referring to the polemic between Ahad Ha'am (Asher Zvi Hirsch Ginsberg) and Moshe Leib Lilienblum which stirred up the Jewish national movement at the time. He takes the side of Ahad Ha'am, and call upon him and his fellows to join in a new national-interpretive initiative. In Alexandrov's opinion the contradiction between religious life and the sciences and enlightenment finds its dialectic culmination in Nationalism, which embodies authenticity, morality and rationality. National life will replace religious life, which hinges solely upon reward and punishment. Like Ahad Ha'am, Alexandrov combines a striving to modernize Judaism with a call to return to the traditional sources which carry its national values. For this purpose he wishes to establish a Religious-Academic institution in Jerusalem, which will engage in reinterpreting traditional sources in such a way as to remold Judaism.",
#     "genre": "Article",
#     "committee_deposit": "",
#     "committee_id": "",
#     "submitter": 1006600,
#     "organization": "",
#     "authors": [
#         {
#             "fullname": "Isaac Slater",
#             "given": "Isaac",
#             "family": "Slater",
#             "uni": "tsachisl",
#             "role": "author",
#             "affiliation": ""
#         }
#     ],
#     "author_info": "Slater, Isaac : tsachisl : personal : author : ; ",
#     "group": [
#         "Jewish Thought in the 20th Century"
#     ],
#     "group_ids": [
#         "1000577"
#     ],
#     "subject": [
#         "983377:Jews--Study and teaching:topical"
#     ],
#     "keyword": [
#         "Jewish studies"
#     ],
#     "type_of_resource": "Text",
#     "language": "English",
#     "notes": "",
#     "notes_unchanged": "",
#     "type_of_license": "All Rights Reserved",
#     "record_content_source": "HumCORE",
#     "record_creation_date": "2016-11-26T16:35:22Z",
#     "record_change_date": "2016-11-26T16:35:22Z",
#     "member_of": "hccollection:1",
#     "published": "published",
#     "publication-type": "journal-article",
#     "publisher": "Bar-Ilan University Press",
#     "date": "2016",
#     "date_issued": "2016",
#     "book_journal_title": "Daat - A journal of Jewish Philosophy & Kabbalah",
#     "volume": "82",
#     "issue": "",
#     "start_page": "285",
#     "end_page": "319",
#     "issn": "",
#     "doi": "",
#     "embargoed": "no",
#     "handle": "http://dx.doi.org/10.17613/M6BP51",
#     "deposit_doi": "doi:10.17613/M6BP51",
#     "record_identifier": "1000361-170",
#     "subject_ids": [
#         "3117"
#     ],
#     "society_id": [
#         "ajs",
#         "hc"
#     ],
#     "datastream_id": "CONTENT",
#     "filename": "slater-religion-and-nationalism-in-the-thought-of-shmuel-alexandrov.pdf",
#     "filetype": "application/pdf",
#     "filesize": "382961",
#     "fileloc": "/srv/www/commons/current/web/app/uploads/humcore/o_1b2gn32v4ub61osv1o22ju716767.pdf.slater-religion-and-nationalism-in-the-thought-of-shmuel-alexandrov.pdf",
#     "thumb_datastream_id": "",
#     "thumb_filename": "",
#     "file_pid": "hc:10054",
#     "institution": "",
#     "keyword_ids": "",
#     "edition": "",
#     "url": "",
#     "book_author": "",
#     "chapter": "",
#     "isbn": "",
#     "deposit_for_others": "",
#     "conference_title": "",
#     "conference_organization": "",
#     "conference_location": "",
#     "conference_date": "",
#     "meeting_title": "",
#     "meeting_organization": "",
#     "meeting_location": "",
#     "meeting_date": "",
#     "embargo_end_date": "",
#     "subjects": ""
# }

# %%
import jsonlines

file_path = '/Users/ianscott/Development/invenio-record-importer/invenio_record_importer/data/serialized_data.jsonl'

with jsonlines.open(file_path) as reader:
    iterlist = list(iter(reader))
    first_object = [r for r in iterlist if r["metadata"]["identifiers"][0]["identifier"] == "hc:10427"][0]
    pretty_printed_object = json.dumps(first_object, indent=4)
    print(pretty_printed_object)
# Out:
# {
#     "parent": {
#         "access": {
#             "owned_by": [
#                 {
#                     "user": "1007339"
#                 }
#             ]
#         }
#     },
#     "custom_fields": {
#         "kcr:commons_domain": "hcommons.org",
#         "kcr:submitter_email": "jaimierbaron@gmail.com",
#         "kcr:submitter_username": "jbaron99",
#         "hclegacy:submitter_id": "1007339",
#         "hclegacy:collection": "hccollection:1",
#         "hclegacy:submitter_org_memberships": [
#             "hc"
#         ],
#         "hclegacy:previously_published": "published",
#         "hclegacy:groups_for_deposit": [
#             {
#                 "group_identifier": "1000640",
#                 "group_name": "Archives"
#             },
#             {
#                 "group_identifier": "1003403",
#                 "group_name": "Documentary Studies"
#             },
#             {
#                 "group_identifier": "1000635",
#                 "group_name": "History"
#             },
#             {
#                 "group_identifier": "1000598",
#                 "group_name": "Library &amp; Information Science"
#             }
#         ],
#         "hclegacy:record_change_date": "2019-04-12T20:46:59Z",
#         "hclegacy:record_creation_date": "2017-01-23T16:53:34Z",
#         "kcr:user_defined_tags": [
#             "archival footage",
#             "archive",
#             "archives",
#             "found footage",
#             "historiography",
#             "history",
#             "Cultural studies",
#             "Film studies",
#             "Media studies"
#         ],
#         "journal:journal": {
#             "volume": "6",
#             "title": "Projections: The Journal for Movies and Mind",
#             "pages": "102-120",
#             "issue": "2"
#         },
#         "hclegacy:file_location": "/srv/www/commons/current/web/app/uploads/humcore/o_1b763n2k9uvs1fbq1a5d1gtbf997.pdf.jaimie-baron-projections-the-archive-effect.pdf",
#         "hclegacy:file_pid": "hc:10428",
#         "hclegacy:total_views": "373",
#         "hclegacy:total_downloads": "1355"
#     },
#     "metadata": {
#         "resource_type": {
#             "id": "textDocument-journalArticle"
#         },
#         "title": "The Archive Effect: Archival Footage as an Experience of Reception.",
#         "creators": [
#             {
#                 "person_or_org": {
#                     "type": "personal",
#                     "name": "Baron, Jaimie",
#                     "given_name": "Jaimie",
#                     "family_name": "Baron",
#                     "identifiers": [
#                         {
#                             "identifier": "jbaron99",
#                             "scheme": "hc_username"
#                         }
#                     ]
#                 },
#                 "role": {
#                     "id": "author",
#                     "title": {
#                         "en": "Author"
#                     }
#                 }
#             }
#         ],
#         "publication_date": "2012",
#         "identifiers": [
#             {
#                 "identifier": "hc:10427",
#                 "scheme": "hclegacy-pid"
#             },
#             {
#                 "identifier": "1000360-1112",
#                 "scheme": "hclegacy-record-id"
#             },
#             {
#                 "identifier": "10.17613/M6FG9D",
#                 "scheme": "datacite-doi"
#             },
#             {
#                 "identifier": "https://doi.org/10.17613/M6FG9D",
#                 "scheme": "url"
#             }
#         ],
#         "languages": [
#             {
#                 "id": "eng",
#                 "title": {
#                     "en": "English"
#                 }
#             }
#         ],
#         "rights": [
#             {
#                 "id": "arr"
#             }
#         ],
#         "description": "In recent years, \"the archive\" as both a concept and an object has been undergoing a transformation. The increased availability of still and video cameras, analog and then digital, has led to a proliferation of indexical documents outside of official archives and prompted questions about what constitutes an \"archive,\" and, hence, what constitute \"archival documents.\" At the same time, filmmakers are appropriating sounds and images from various sources, thereby breaking down the distinction between \"found\" and \"archival\" documents. This situation calls for a reformulation of the very notion of the archival document. This article reframes the archival document not as an object but as a spectatorial experience or a relationship between viewer and text. I contend that certain appropriated audiovisual documents produce for the viewer what I call the \"archive effect\" and that this encounter endows these documents with a particular kind of authority as \"evidence.\"",
#         "dates": [
#             {
#                 "date": "Winter 2012",
#                 "type": {
#                     "id": "issued",
#                     "title": {
#                         "en": "Issued",
#                         "de": "Ver\u00f6ffentlicht"
#                     }
#                 },
#                 "description": "Publication date"
#             }
#         ],
#         "subjects": [
#             {
#                 "id": "http://id.worldcat.org/fast/885086",
#                 "subject": "Culture--Study and teaching",
#                 "scheme": "FAST-topical"
#             },
#             {
#                 "id": "http://id.worldcat.org/fast/1011313",
#                 "subject": "Mass media--Study and teaching",
#                 "scheme": "FAST-topical"
#             }
#         ],
#         "publisher": "unknown"
#     },
#     "files": {
#         "enabled": true,
#         "entries": {
#             "jaimie-baron-projections-the-archive-effect.pdf": {
#                 "key": "jaimie-baron-projections-the-archive-effect.pdf",
#                 "mimetype": "application/pdf",
#                 "size": "273999"
#             }
#         },
#         "default_preview": "jaimie-baron-projections-the-archive-effect.pdf"
#     },
#     "pids": {
#         "doi": {
#             "identifier": "10.17613/M6FG9D",
#             "provider": "datacite",
#             "client": "datacite"
#         }
#     },
#     "updated": "2019-04-12T20:46:59Z",
#     "created": "2017-01-23T16:53:34Z",
#     "record_source": "knowledgeCommons"
# }

# %%
import jsonlines

file_path = '/Users/ianscott/Development/invenio-record-importer/invenio_record_importer/data/serialized_data.jsonl'

with jsonlines.open(file_path) as reader:
    first_object = next(iter(reader))
    pretty_printed_object = json.dumps(first_object, indent=4)
    print(pretty_printed_object)
# Out:
# {
#     "parent": {
#         "access": {
#             "owned_by": [
#                 {
#                     "user": "1006600"
#                 }
#             ]
#         }
#     },
#     "custom_fields": {
#         "kcr:commons_domain": "ajs.hcommons.org",
#         "kcr:submitter_email": "Tsachisl@gmail.com",
#         "kcr:submitter_username": "tsachisl",
#         "hclegacy:submitter_id": "1006600",
#         "hclegacy:collection": "hccollection:1",
#         "hclegacy:submitter_org_memberships": [
#             "ajs",
#             "hc"
#         ],
#         "hclegacy:previously_published": "published",
#         "hclegacy:groups_for_deposit": [
#             {
#                 "group_identifier": "1000577",
#                 "group_name": "Jewish Thought in the 20th Century"
#             }
#         ],
#         "hclegacy:record_change_date": "2016-11-26T16:35:22Z",
#         "hclegacy:record_creation_date": "2016-11-26T16:35:22Z",
#         "kcr:user_defined_tags": [
#             "Jewish studies"
#         ],
#         "journal:journal": {
#             "volume": "82",
#             "title": "Daat - A journal of Jewish Philosophy & Kabbalah",
#             "pages": "285-319"
#         },
#         "hclegacy:file_location": "/srv/www/commons/current/web/app/uploads/humcore/o_1b2gn32v4ub61osv1o22ju716767.pdf.slater-religion-and-nationalism-in-the-thought-of-shmuel-alexandrov.pdf",
#         "hclegacy:file_pid": "hc:10054",
#         "hclegacy:total_views": "33",
#         "hclegacy:total_downloads": "52"
#     },
#     "metadata": {
#         "resource_type": {
#             "id": "textDocument-journalArticle"
#         },
#         "title": "Religious Cultural Zionism: Religion and Nationalism in the Thought of Shmuel Alexandrov",
#         "creators": [
#             {
#                 "person_or_org": {
#                     "type": "personal",
#                     "name": "Slater, Isaac",
#                     "given_name": "Isaac",
#                     "family_name": "Slater",
#                     "identifiers": [
#                         {
#                             "identifier": "tsachisl",
#                             "scheme": "hc_username"
#                         }
#                     ]
#                 },
#                 "role": {
#                     "id": "author",
#                     "title": {
#                         "en": "Author"
#                     }
#                 }
#             }
#         ],
#         "publication_date": "2016",
#         "identifiers": [
#             {
#                 "identifier": "hc:10053",
#                 "scheme": "hclegacy-pid"
#             },
#             {
#                 "identifier": "1000361-170",
#                 "scheme": "hclegacy-record-id"
#             },
#             {
#                 "identifier": "10.17613/M6BP51",
#                 "scheme": "datacite-doi"
#             },
#             {
#                 "identifier": "https://doi.org/10.17613/M6BP51",
#                 "scheme": "url"
#             }
#         ],
#         "languages": [
#             {
#                 "id": "eng",
#                 "title": {
#                     "en": "English"
#                 }
#             }
#         ],
#         "rights": [
#             {
#                 "id": "arr"
#             }
#         ],
#         "description": "Rabbi Shmuel Alexandrov is a fascinating yet neglected thinker. In this paper I examine the earlier stage of his thought, which would serve as the basis for researching his later thought, by analyzing the discourse 'Religious Fire and National Spirit [esh dat ve'ruch leumi]'. Alexandrov is referring to the polemic between Ahad Ha'am (Asher Zvi Hirsch Ginsberg) and Moshe Leib Lilienblum which stirred up the Jewish national movement at the time. He takes the side of Ahad Ha'am, and call upon him and his fellows to join in a new national-interpretive initiative. In Alexandrov's opinion the contradiction between religious life and the sciences and enlightenment finds its dialectic culmination in Nationalism, which embodies authenticity, morality and rationality. National life will replace religious life, which hinges solely upon reward and punishment. Like Ahad Ha'am, Alexandrov combines a striving to modernize Judaism with a call to return to the traditional sources which carry its national values. For this purpose he wishes to establish a Religious-Academic institution in Jerusalem, which will engage in reinterpreting traditional sources in such a way as to remold Judaism.",
#         "subjects": [
#             {
#                 "id": "http://id.worldcat.org/fast/983377",
#                 "subject": "Jews--Study and teaching",
#                 "scheme": "FAST-topical"
#             }
#         ],
#         "publisher": "Bar-Ilan University Press"
#     },
#     "files": {
#         "enabled": true,
#         "entries": {
#             "slater-religion-and-nationalism-in-the-thought-of-shmuel-alexandrov.pdf": {
#                 "key": "slater-religion-and-nationalism-in-the-thought-of-shmuel-alexandrov.pdf",
#                 "mimetype": "application/pdf",
#                 "size": "382961"
#             }
#         },
#         "default_preview": "slater-religion-and-nationalism-in-the-thought-of-shmuel-alexandrov.pdf"
#     },
#     "pids": {
#         "doi": {
#             "identifier": "10.17613/M6BP51",
#             "provider": "datacite",
#             "client": "datacite"
#         }
#     },
#     "updated": "2016-11-26T16:35:22Z",
#     "created": "2016-11-26T16:35:22Z",
#     "record_source": "knowledgeCommons"
# }

# %%
import iso639

iso639.Language.from_part2b('swa')
# Out:
# Language(part3='swa', part2b='swa', part2t='swa', part1='sw', scope='M', type='L', status='A', name='Swahili (macrolanguage)', comment=None, other_names=None, macrolanguage=None, retire_reason=None, retire_change_to=None, retire_remedy=None, retire_date=None)

# %%
a = ['a', 'b', 'c']
b = ['c', 'd', 'e']
a.extend(b)
print(a)
# Out:
# ['a', 'b', 'c', 'c', 'd', 'e']

# %%
import json

file_path = '/Users/ianscott/Development/kcr-untracked-files/records-for-import.json'

with open(file_path) as file:
    data = json.load(file)

    objects = [d for d in data if d["id"] == "hc:10125"]
    pretty_printed_object = json.dumps(objects, indent=4)

    print(pretty_printed_object)
# Out:
# [
#     {
#         "deposit_post_id": "533",
#         "total_downloads": "92",
#         "total_views": "68",
#         "submitter_login": "mmarmor",
#         "submitter_email": "max.marmor@kressfoundation.org",
#         "blog_id": "1000360",
#         "domain": "hcommons.org",
#         "id": "hc:10125",
#         "pid": "hc:10125",
#         "creator": "HumCORE",
#         "title": "\u2026 Par che sia mio destino\u2026: The prophetic dream in Leonardo and in Dante.",
#         "title_unchanged": "\u2026 Par che sia mio destino\u2026: The prophetic dream in Leonardo and in Dante.",
#         "abstract": "Argues for Dante's impact on Leonardo da Vinci's famous \"childhood memory.\"",
#         "abstract_unchanged": "Argues for Dante's impact on Leonardo da Vinci's famous \"childhood memory.\"",
#         "genre": "Article",
#         "committee_deposit": "",
#         "committee_id": "",
#         "submitter": 1006731,
#         "organization": "",
#         "authors": [
#             {
#                 "given": "Max",
#                 "family": "Marmor",
#                 "fullname": "Max Marmor",
#                 "uni": "mmarmor",
#                 "role": "author",
#                 "affiliation": ""
#             }
#         ],
#         "author_info": "Marmor, Max : mmarmor : personal : author : ; ",
#         "group": [
#             null
#         ],
#         "group_ids": [
#             ""
#         ],
#         "subject": [
#             "815177:Art:topical",
#             "958235:History:topical"
#         ],
#         "keyword": [
#             "renaissance",
#             "Art history"
#         ],
#         "type_of_resource": "Text",
#         "language": "English",
#         "notes": "",
#         "notes_unchanged": "Offprint pagination differs from original publication",
#         "type_of_license": "All Rights Reserved",
#         "record_content_source": "HumCORE",
#         "record_creation_date": "2016-12-03T15:13:49Z",
#         "record_change_date": "2016-12-03T15:25:00Z",
#         "member_of": "hccollection:1",
#         "published": "published",
#         "publication-type": "journal-article",
#         "publisher": "",
#         "date": "2005",
#         "date_issued": "2005",
#         "book_journal_title": "Raccolta Vinciana",
#         "volume": "XXXI",
#         "issue": "",
#         "start_page": "[145]",
#         "end_page": "180",
#         "issn": "",
#         "doi": "",
#         "embargoed": "no",
#         "handle": "http://dx.doi.org/10.17613/M6PS4S",
#         "deposit_doi": "doi:10.17613/M6PS4S",
#         "record_identifier": "1000360-533",
#         "subject_ids": [
#             "1994"
#         ],
#         "society_id": [
#             "caa",
#             "hc"
#         ],
#         "datastream_id": "CONTENT",
#         "filename": "marmor_par_che_sia_rv-e-print.pdf",
#         "filetype": "application/pdf",
#         "filesize": "202117",
#         "fileloc": "/srv/www/commons/current/web/app/uploads/humcore/o_1b32jtmpt6561alrqqvp2hmod7.pdf.marmor_par_che_sia_rv-e-print.pdf",
#         "thumb_datastream_id": "",
#         "thumb_filename": "",
#         "file_pid": "hc:10126",
#         "institution": "",
#         "keyword_ids": [
#             "2958"
#         ],
#         "edition": "",
#         "url": "",
#         "book_author": "",
#         "chapter": "",
#         "isbn": "",
#         "deposit_for_others": "",
#         "conference_title": "",
#         "conference_organization": "",
#         "conference_location": "",
#         "conference_date": "",
#         "meeting_title": "",
#         "meeting_organization": "",
#         "meeting_location": "",
#         "meeting_date": "",
#         "embargo_end_date": "",
#         "subjects": ""
#     }
# ]

# %%
import json
import arrow

file_path = '/Users/ianscott/Development/kcr-untracked-files/records-for-import.json'

with open(file_path) as file:
    data = json.load(file)

    first_object = iter(d for d in data if d["embargoed"] != "no" and d["embargo_end_date"] and arrow.get(d["embargo_end_date"], 'MM/DD/YYYY') > arrow.utcnow()).__next__()
    pretty_printed_object = json.dumps(first_object, indent=4)

    print(pretty_printed_object)
# Out:
# {
#     "deposit_post_id": "40713",
#     "total_downloads": "22",
#     "total_views": "20",
#     "submitter_login": "alexmcnair",
#     "submitter_email": "alex_mcnair@baylor.edu",
#     "blog_id": "1000360",
#     "domain": "hcommons.org",
#     "id": "hc:33641",
#     "pid": "hc:33641",
#     "creator": "HumCORE",
#     "title": "El Cid Campeador between Luz\u00e1n and Lorca: Recovering a Nineteenth-Century Pop-Culture Favorite",
#     "title_unchanged": "El Cid Campeador between Luz\u00e1n and Lorca: Recovering a Nineteenth-Century Pop-Culture Favorite",
#     "abstract": "Only a small number of fragments, which could be categorized (generously) as \u201cmedieval,\u201d actually survive in modern ballad traditions. As it turns out, however, one could in fact hear hundreds of verses about the Cid being recited in the streets of Spanish towns and cities in the nineteenth century. But they were verses that survived precisely because those who Luz\u00e1n called \u201cla gente vulgar\u201d were anything but mindless consumers; their baroque tastes and romantic preferences helped to shape a popular version of El Cid in theaters and on street corners in the eighteenth and nineteenth centuries. This paper will explore examples of pliegos sueltos (broadsides from the hand-press and early machine-press eras) that attest to the popularity of Cidian ballads that trace their roots to the Spanish baroque rather than Medieval folklore.",
#     "abstract_unchanged": "Only a small number of fragments, which could be categorized (generously) as \u201cmedieval,\u201d actually survive in modern ballad traditions.  As it turns out, however, one could in fact hear hundreds of verses about the Cid being recited in the streets of Spanish towns and cities in the nineteenth century.  But they were verses that survived precisely because those who Luz\u00e1n called \u201cla gente vulgar\u201d were anything but mindless consumers; their baroque tastes and romantic preferences helped to shape a popular version of El Cid in theaters and on street corners in the eighteenth and nineteenth centuries.  This paper will explore examples of pliegos sueltos (broadsides from the hand-press and early machine-press eras) that attest to the popularity of Cidian ballads that trace their roots to the Spanish baroque rather than Medieval folklore. ",
#     "genre": "Conference paper",
#     "committee_deposit": "",
#     "committee_id": "",
#     "submitter": "1022318",
#     "organization": "Baylor University, Department Of Modern Languages And Cultures",
#     "authors": [
#         {
#             "given": "Alex",
#             "family": "McNair",
#             "fullname": "Alexander J McNair",
#             "uni": "alexmcnair",
#             "role": "author",
#             "affiliation": "Baylor University, Department Of Modern Languages And Cultures"
#         }
#     ],
#     "author_info": "McNair, Alex : alexmcnair : personal : author : Baylor University, Department Of Modern Languages And Cultures; ",
#     "group": [
#         "Medieval Studies",
#         "Renaissance / Early Modern Studies",
#         "Spanish Golden Age Literature"
#     ],
#     "group_ids": [
#         "1000753",
#         "1002950",
#         "1003009"
#     ],
#     "subject": [
#         "930306:Folklore:topical",
#         "1119851:Sixteenth century:topical",
#         "1113663:Seventeenth century:topical"
#     ],
#     "keyword": [
#         "1600-1900",
#         "ballads",
#         "El Cid"
#     ],
#     "type_of_resource": "Text",
#     "language": "English",
#     "notes": "",
#     "notes_unchanged": "",
#     "type_of_license": "All Rights Reserved",
#     "record_content_source": "HumCORE",
#     "record_creation_date": "2020-12-14T21:14:45Z",
#     "record_change_date": "2022-07-05T22:03:52Z",
#     "member_of": "hccollection:1",
#     "published": "not-published",
#     "publication-type": "none",
#     "publisher": "",
#     "date": "2 October 2020",
#     "date_issued": "2020",
#     "book_journal_title": "",
#     "volume": "",
#     "issue": "",
#     "start_page": "",
#     "end_page": "",
#     "issn": "",
#     "doi": "",
#     "embargoed": "yes",
#     "handle": "http://dx.doi.org/10.17613/7mqx-s132",
#     "deposit_doi": "doi:10.17613/7mqx-s132",
#     "record_identifier": "1000360-40713",
#     "subject_ids": [
#         "1020767",
#         "1022037"
#     ],
#     "society_id": [
#         "hc",
#         "mla"
#     ],
#     "datastream_id": "CONTENT",
#     "filename": "tema-2020-paper.pdf",
#     "filetype": "application/pdf",
#     "filesize": "171716",
#     "fileloc": "/srv/www/commons/current/web/app/uploads/humcore/2020/12/o_1ephh7khm1tgn1eeegeb8tsgks7.pdf.tema-2020-paper.pdf",
#     "thumb_datastream_id": "",
#     "thumb_filename": "",
#     "file_pid": "hc:33642",
#     "institution": "",
#     "keyword_ids": [
#         "1036652",
#         "3538",
#         "1020888"
#     ],
#     "edition": "",
#     "url": "",
#     "book_author": "",
#     "chapter": "",
#     "isbn": "",
#     "deposit_for_others": "",
#     "conference_title": "Texas Medieval Association",
#     "conference_organization": "Texas Medieval Association, University of North Texas",
#     "conference_location": "UNT, Virtual",
#     "conference_date": "2 October 2020",
#     "meeting_title": "",
#     "meeting_organization": "",
#     "meeting_location": "",
#     "meeting_date": "",
#     "embargo_end_date": "12/31/2099",
#     "subjects": ""
# }

# %%
import dateparser
import arrow
print(dateparser.parse('January-Mar 21'))
print(dateparser.parse('January 21'))
print(dateparser.parse('January 21st'))
print(dateparser.parse('winter 2021'))
print(dateparser.parse('january'))
print(arrow.get(dateparser.parse('03-02-18')).date().isoformat())
# Out:
# None
# 2024-01-21 00:00:00
# 2024-01-21 00:00:00
# None
# 2024-01-03 00:00:00
# 2018-03-02
