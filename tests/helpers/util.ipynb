# %%
import json

file_path = '/Users/ianscott/Development/kcr-untracked-files/records-for-import.json'

with open(file_path) as file:
    data = json.load(file)

    first_object = data[0]
    pretty_printed_object = json.dumps(first_object, indent=4)

    print(pretty_printed_object)
# Out:
# {
#     "deposit_post_id": "170",
#     "total_downloads": "52",
#     "total_views": "33",
#     "submitter_login": "tsachisl",
#     "submitter_email": "Tsachisl@gmail.com",
#     "blog_id": "1000361",
#     "domain": "ajs.hcommons.org",
#     "id": "hc:10053",
#     "pid": "hc:10053",
#     "creator": "HumCORE",
#     "title": "Religious Cultural Zionism: Religion and Nationalism in the Thought of Shmuel Alexandrov",
#     "title_unchanged": "Religious Cultural Zionism: Religion and Nationalism in the Thought of Shmuel Alexandrov",
#     "abstract": "Rabbi Shmuel Alexandrov is a fascinating yet neglected thinker. In this paper I examine the earlier stage of his thought, which would serve as the basis for researching his later thought, by analyzing the discourse 'Religious Fire and National Spirit [esh dat ve'ruch leumi]'. Alexandrov is referring to the polemic between Ahad Ha'am (Asher Zvi Hirsch Ginsberg) and Moshe Leib Lilienblum which stirred up the Jewish national movement at the time. He takes the side of Ahad Ha'am, and call upon him and his fellows to join in a new national-interpretive initiative. In Alexandrov's opinion the contradiction between religious life and the sciences and enlightenment finds its dialectic culmination in Nationalism, which embodies authenticity, morality and rationality. National life will replace religious life, which hinges solely upon reward and punishment. Like Ahad Ha'am, Alexandrov combines a striving to modernize Judaism with a call to return to the traditional sources which carry its national values. For this purpose he wishes to establish a Religious-Academic institution in Jerusalem, which will engage in reinterpreting traditional sources in such a way as to remold Judaism.",
#     "abstract_unchanged": "Rabbi Shmuel Alexandrov is a fascinating yet neglected thinker. In this paper I examine the earlier stage of his thought, which would serve as the basis for researching his later thought, by analyzing the discourse 'Religious Fire and National Spirit [esh dat ve'ruch leumi]'. Alexandrov is referring to the polemic between Ahad Ha'am (Asher Zvi Hirsch Ginsberg) and Moshe Leib Lilienblum which stirred up the Jewish national movement at the time. He takes the side of Ahad Ha'am, and call upon him and his fellows to join in a new national-interpretive initiative. In Alexandrov's opinion the contradiction between religious life and the sciences and enlightenment finds its dialectic culmination in Nationalism, which embodies authenticity, morality and rationality. National life will replace religious life, which hinges solely upon reward and punishment. Like Ahad Ha'am, Alexandrov combines a striving to modernize Judaism with a call to return to the traditional sources which carry its national values. For this purpose he wishes to establish a Religious-Academic institution in Jerusalem, which will engage in reinterpreting traditional sources in such a way as to remold Judaism.",
#     "genre": "Article",
#     "committee_deposit": "",
#     "committee_id": "",
#     "submitter": 1006600,
#     "organization": "",
#     "authors": [
#         {
#             "fullname": "Isaac Slater",
#             "given": "Isaac",
#             "family": "Slater",
#             "uni": "tsachisl",
#             "role": "author",
#             "affiliation": ""
#         }
#     ],
#     "author_info": "Slater, Isaac : tsachisl : personal : author : ; ",
#     "group": [
#         "Jewish Thought in the 20th Century"
#     ],
#     "group_ids": [
#         "1000577"
#     ],
#     "subject": [
#         "983377:Jews--Study and teaching:topical"
#     ],
#     "keyword": [
#         "Jewish studies"
#     ],
#     "type_of_resource": "Text",
#     "language": "English",
#     "notes": "",
#     "notes_unchanged": "",
#     "type_of_license": "All Rights Reserved",
#     "record_content_source": "HumCORE",
#     "record_creation_date": "2016-11-26T16:35:22Z",
#     "record_change_date": "2016-11-26T16:35:22Z",
#     "member_of": "hccollection:1",
#     "published": "published",
#     "publication-type": "journal-article",
#     "publisher": "Bar-Ilan University Press",
#     "date": "2016",
#     "date_issued": "2016",
#     "book_journal_title": "Daat - A journal of Jewish Philosophy & Kabbalah",
#     "volume": "82",
#     "issue": "",
#     "start_page": "285",
#     "end_page": "319",
#     "issn": "",
#     "doi": "",
#     "embargoed": "no",
#     "handle": "http://dx.doi.org/10.17613/M6BP51",
#     "deposit_doi": "doi:10.17613/M6BP51",
#     "record_identifier": "1000361-170",
#     "subject_ids": [
#         "3117"
#     ],
#     "society_id": [
#         "ajs",
#         "hc"
#     ],
#     "datastream_id": "CONTENT",
#     "filename": "slater-religion-and-nationalism-in-the-thought-of-shmuel-alexandrov.pdf",
#     "filetype": "application/pdf",
#     "filesize": "382961",
#     "fileloc": "/srv/www/commons/current/web/app/uploads/humcore/o_1b2gn32v4ub61osv1o22ju716767.pdf.slater-religion-and-nationalism-in-the-thought-of-shmuel-alexandrov.pdf",
#     "thumb_datastream_id": "",
#     "thumb_filename": "",
#     "file_pid": "hc:10054",
#     "institution": "",
#     "keyword_ids": "",
#     "edition": "",
#     "url": "",
#     "book_author": "",
#     "chapter": "",
#     "isbn": "",
#     "deposit_for_others": "",
#     "conference_title": "",
#     "conference_organization": "",
#     "conference_location": "",
#     "conference_date": "",
#     "meeting_title": "",
#     "meeting_organization": "",
#     "meeting_location": "",
#     "meeting_date": "",
#     "embargo_end_date": "",
#     "subjects": ""
# }

# %%
import jsonlines

file_path = '/Users/ianscott/Development/invenio-record-importer/invenio_record_importer/data/serialized_data.jsonl'

with jsonlines.open(file_path) as reader:
    first_object = next(iter(reader))
    pretty_printed_object = json.dumps(first_object, indent=4)
    print(pretty_printed_object)
# Out:
# {
#     "parent": {
#         "access": {
#             "owned_by": [
#                 {
#                     "user": "1006600"
#                 }
#             ]
#         }
#     },
#     "custom_fields": {
#         "kcr:commons_domain": "ajs.hcommons.org",
#         "kcr:submitter_email": "Tsachisl@gmail.com",
#         "kcr:submitter_username": "tsachisl",
#         "hclegacy:submitter_id": "1006600",
#         "hclegacy:collection": "hccollection:1",
#         "hclegacy:submitter_org_memberships": [
#             "ajs",
#             "hc"
#         ],
#         "hclegacy:previously_published": "published",
#         "hclegacy:groups_for_deposit": [
#             {
#                 "group_identifier": "1000577",
#                 "group_name": "Jewish Thought in the 20th Century"
#             }
#         ],
#         "hclegacy:record_change_date": "2016-11-26T16:35:22Z",
#         "hclegacy:record_creation_date": "2016-11-26T16:35:22Z",
#         "kcr:user_defined_tags": [
#             "Jewish studies"
#         ],
#         "journal:journal": {
#             "volume": "82",
#             "title": "Daat - A journal of Jewish Philosophy & Kabbalah",
#             "pages": "285-319"
#         },
#         "hclegacy:file_location": "/srv/www/commons/current/web/app/uploads/humcore/o_1b2gn32v4ub61osv1o22ju716767.pdf.slater-religion-and-nationalism-in-the-thought-of-shmuel-alexandrov.pdf",
#         "hclegacy:file_pid": "hc:10054",
#         "hclegacy:total_views": "33",
#         "hclegacy:total_downloads": "52"
#     },
#     "metadata": {
#         "resource_type": {
#             "id": "textDocument-journalArticle"
#         },
#         "title": "Religious Cultural Zionism: Religion and Nationalism in the Thought of Shmuel Alexandrov",
#         "creators": [
#             {
#                 "person_or_org": {
#                     "type": "personal",
#                     "name": "Slater, Isaac",
#                     "given_name": "Isaac",
#                     "family_name": "Slater",
#                     "identifiers": [
#                         {
#                             "identifier": "tsachisl",
#                             "scheme": "hc_username"
#                         }
#                     ]
#                 },
#                 "role": {
#                     "id": "author",
#                     "title": {
#                         "en": "Author"
#                     }
#                 }
#             }
#         ],
#         "publication_date": "2016",
#         "identifiers": [
#             {
#                 "identifier": "hc:10053",
#                 "scheme": "hclegacy-pid"
#             },
#             {
#                 "identifier": "1000361-170",
#                 "scheme": "hclegacy-record-id"
#             },
#             {
#                 "identifier": "10.17613/M6BP51",
#                 "scheme": "datacite-doi"
#             },
#             {
#                 "identifier": "https://doi.org/10.17613/M6BP51",
#                 "scheme": "url"
#             }
#         ],
#         "languages": [
#             {
#                 "id": "eng",
#                 "title": {
#                     "en": "English"
#                 }
#             }
#         ],
#         "rights": [
#             {
#                 "id": "arr"
#             }
#         ],
#         "description": "Rabbi Shmuel Alexandrov is a fascinating yet neglected thinker. In this paper I examine the earlier stage of his thought, which would serve as the basis for researching his later thought, by analyzing the discourse 'Religious Fire and National Spirit [esh dat ve'ruch leumi]'. Alexandrov is referring to the polemic between Ahad Ha'am (Asher Zvi Hirsch Ginsberg) and Moshe Leib Lilienblum which stirred up the Jewish national movement at the time. He takes the side of Ahad Ha'am, and call upon him and his fellows to join in a new national-interpretive initiative. In Alexandrov's opinion the contradiction between religious life and the sciences and enlightenment finds its dialectic culmination in Nationalism, which embodies authenticity, morality and rationality. National life will replace religious life, which hinges solely upon reward and punishment. Like Ahad Ha'am, Alexandrov combines a striving to modernize Judaism with a call to return to the traditional sources which carry its national values. For this purpose he wishes to establish a Religious-Academic institution in Jerusalem, which will engage in reinterpreting traditional sources in such a way as to remold Judaism.",
#         "subjects": [
#             {
#                 "id": "http://id.worldcat.org/fast/983377",
#                 "subject": "Jews--Study and teaching",
#                 "scheme": "FAST-topical"
#             }
#         ],
#         "publisher": "Bar-Ilan University Press"
#     },
#     "files": {
#         "enabled": true,
#         "entries": {
#             "slater-religion-and-nationalism-in-the-thought-of-shmuel-alexandrov.pdf": {
#                 "key": "slater-religion-and-nationalism-in-the-thought-of-shmuel-alexandrov.pdf",
#                 "mimetype": "application/pdf",
#                 "size": "382961"
#             }
#         },
#         "default_preview": "slater-religion-and-nationalism-in-the-thought-of-shmuel-alexandrov.pdf"
#     },
#     "pids": {
#         "doi": {
#             "identifier": "10.17613/M6BP51",
#             "provider": "datacite",
#             "client": "datacite"
#         }
#     },
#     "updated": "2016-11-26T16:35:22Z",
#     "created": "2016-11-26T16:35:22Z",
#     "record_source": "knowledgeCommons"
# }

# %%
import iso639

iso639.Language.from_part2b('swa')
# Out:
# Language(part3='swa', part2b='swa', part2t='swa', part1='sw', scope='M', type='L', status='A', name='Swahili (macrolanguage)', comment=None, other_names=None, macrolanguage=None, retire_reason=None, retire_change_to=None, retire_remedy=None, retire_date=None)
